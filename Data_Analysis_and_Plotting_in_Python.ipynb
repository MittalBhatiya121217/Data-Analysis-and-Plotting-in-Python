# %% [markdown]
# # Data Analysis and Plotting in Python
#
# This tutorial is...
# * introductory and geared towards people new to Python
# * interactive with simple exercises along the way
#
# We'll be introducing Pandas for data handling and analysis, and using Matplotlib, Seaborn and Bokeh for visualization
#
# ** Please execute sequentially **

# %% [markdown]
# ## What is pandas?
#
# [Pandas](https://pandas.pydata.org/pandas-docs/stable/) provides objects for working with data - `Series` and `DataFrame`
#
# Data structures have methods for manipulating data eg. indexing, sorting, grouping, filling in missing data
#
# Pandas does not provide modeling tools eg. regression, prediction
# * These tools are found in packages such as `scikit-learn` and `statsmodels`, which are built on top of pandas

# %% [markdown]
# ## DataFrames
#
# A `DataFrame` combines multiple 'columns' of data into a two-dimensional object, similar to a spreadsheet

# %% [markdown]
# **Q1 Display the image dataframe.jpg(5 points)**

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg

plt.title("Image")
plt.xlabel("X columns")
plt.ylabel("Y rows")

image = mpimg.imread("/content/dataframe.jpg")
plt.imshow(image)
plt.show()

# %% [markdown]
# here, we are displaying the image using the matplotlic library and give titles and labels of the image.
#
# from matplotlib import pyplot as plt this is used for create pyplot which is used for show image. plt is alias of the matplotlib library.
#
# from matplotlib import image as mpimg this is used for the loading the image here for that we are using the mpimg from matplotlib. mpimg is the alias of image from matplotlib.
#
# after that here we are setting the titles and labels of the image.
#
# plt.title("Image") this is used for give the title of the image as Image using the title() function along with the plt.
#
# plt.xlabel("X column") this is used for setting the label of the x-axis as "X column".
#
# plt.ylabel("Y rows") this is used for setting the label of the y-axis as a "Y rows".
#
# after that now we are loading and displaying the image for loading the image we are using imread() function.
# image = mpimg.imread("/content/dataframe.jpg") here we are loading the image using the imread() function  with image path inside along with the mpimg alias of matplotlib.
#
# plt.imshow(image) this is used for displaying the image for that we are using the imshow() function for showing the image. for that we are first using the plt alias of matplotlib along with the imshow() function inside the name of the image.
#
# talking about image first we are loading and displaying the image using the matplotlib. in the image its shown that in the rows are in the axis=0 while columns are in the axis=1. this image is specify the data representation in the dataframe.

# %% [markdown]
# We will create a `DataFrame` by reading in a CSV file and assigning it to the variable name `data`

# %% [markdown]
# ### Info on the data set
#
# * The data come from ['Assessing the Rate of Replication in Economics'](https://www.aeaweb.org/articles?id=10.1257/aer.p20171119), *American Economics Review: Papers & Proceedings*, 2017
# * The dataframe `data` contains 70 empirical papers from AER's 100th volume
# * `Web of Science`: number of Web of Science citations
# * `Top 200`: number of Top 200 economics journal citations
# * `Google Scholar`: number of Google Scholar citations
# * `Replications`: number of citations that are replications of the paper
# * `Extensions`: number of citations that are extensions of the paper
# * `Both`: number of citations that are either replications or extensions of the paper

# %%
import pandas as pd  # Import the package

data = pd.read_csv('/content/data.csv')
data.head()
# Out:
#    ID                                              Title  Web of Science  \
# 0   2  Learning about a New Technology: Pineapple in ...             176
# 1   3       Multiple-Product Firms and Product Switching             111
# 2   4  Momma's Got the Pill": How Anthony Comstock an...              23
# 3   5              Matching and Sorting in Online Dating              75
# 4   6  Entry, Exit, and Investment-Specific Technical...               9
#
#    Top 200  Google Scholar            Field  Replications  Extensions  Both
# 0    108.0            1246      Development           1.0        10.0  11.0
# 1     74.0             764         Labor/IO           1.0         2.0   3.0
# 2     15.0              98         Labor/IO           2.0         0.0   2.0
# 3     23.0             326         Labor/IO           0.0         5.0   5.0
# 4      9.0              38  Macro/Int/Trade           0.0         0.0   0.0

# %% [markdown]
# Here, we are using the pandas library for reading the data using the read_csv() function. For displaying the data we are using the head() function for displaying the first few rows of the detailed data alongs with the title of the columns.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              70 non-null     int64
#  1   Title           70 non-null     object
#  2   Web of Science  70 non-null     int64
#  3   Top 200         70 non-null     float64
#  4   Google Scholar  70 non-null     int64
#  5   Field           70 non-null     object
#  6   Replications    70 non-null     float64
#  7   Extensions      70 non-null     float64
#  8   Both            70 non-null     float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 5.0+ KB

# %% [markdown]
# Here, we are getting information of the data using the info() function which is use for getting information about the total not null values of the rows and print the columns data types.

# %% [markdown]
# We can access individual columns of data, returning a `Series`

# %%
data['Top 200'].head()
# Out:
# 0    108.0
# 1     74.0
# 2     15.0
# 3     23.0
# 4      9.0
# Name: Top 200, dtype: float64

# %% [markdown]
# here, we are displaying data for only one column TOP 200 using the head() function.  as we can see in the data its only read top rows of the data from this column.

# %% [markdown]
# We can also select multiple columns, returning a new dataframe

# %%
data[['Title', 'Top 200']].head()
# Out:
#                                                Title  Top 200
# 0  Learning about a New Technology: Pineapple in ...    108.0
# 1       Multiple-Product Firms and Product Switching     74.0
# 2  Momma's Got the Pill": How Anthony Comstock an...     15.0
# 3              Matching and Sorting in Online Dating     23.0
# 4  Entry, Exit, and Investment-Specific Technical...      9.0

# %% [markdown]
# We are using the two different columns for displaying the data for that we are using two columns name in the dataset alias data and along with that using the head() for reading the first rows of the two columns.

# %% [markdown]
# We can add a new column to our dataframe like so

# %%
data['Total'] = data['Web of Science'] + data['Top 200'] + data['Google Scholar']
data.head()
# Out:
#    ID                                              Title  Web of Science  \
# 0   2  Learning about a New Technology: Pineapple in ...             176
# 1   3       Multiple-Product Firms and Product Switching             111
# 2   4  Momma's Got the Pill": How Anthony Comstock an...              23
# 3   5              Matching and Sorting in Online Dating              75
# 4   6  Entry, Exit, and Investment-Specific Technical...               9
#
#    Top 200  Google Scholar            Field  Replications  Extensions  Both  \
# 0    108.0            1246      Development           1.0        10.0  11.0
# 1     74.0             764         Labor/IO           1.0         2.0   3.0
# 2     15.0              98         Labor/IO           2.0         0.0   2.0
# 3     23.0             326         Labor/IO           0.0         5.0   5.0
# 4      9.0              38  Macro/Int/Trade           0.0         0.0   0.0
#
#     Total
# 0  1530.0
# 1   949.0
# 2   136.0
# 3   424.0
# 4    56.0

# %% [markdown]
# here, we are creating the new column name as Total and for gethering data for this column we are using the other columns data for calculate. for getting the details for column total we are performing addition opertation to the columns such as web of services, Top 200, google scholar. after completion of this we are finally displaying the data using the head() function.

# %% [markdown]
# **Q2 Calculate mean of each column in a dataset(5 points)**

# %%
data.mean(numeric_only=True)
# Out:
# ID                 52.485714
# Web of Science     42.071429
# Top 200            22.257143
# Google Scholar    227.571429
# Replications        0.742857
# Extensions          1.728571
# Both                2.471429
# Total             291.900000
# dtype: float64

# %% [markdown]
# here, for getting the average of the each column  for the numeric data we are using the mean() function.
# mean() function passed with the argument numeric_value = true which means its only consider numeric data for calculating the mean. focusing on the data Replications have the smallest mean 0.742857 while in contrast, total column have the highest mean which is 291.900000.
#
# here we are calculating the mean values of the each columns in the dataset for analysis.
#
# first talking about id here the average value for the id is 52.49. web of science have the 42.07 mean value.this is define the measure of paper and publication.
#
# for Top 200 the mean is 22.26.  this data is represent about the publication. and google scolar mean is 227.57. which means that total 227 number of citation mentioned on google scholar for each of the paper.
#
# Replication mean is 0.74 this will represent the average number of the time when paper is replicate.
#
# extensions mean is 1.73 which represent the number of time the paper is extended.
# both has 2.47 mean. this is represent the average total number of the both replication and extension of the each paper.
#
# Total mean is 291.90 this mean represent as total numeric matrics for the paper.
#
# all in all, here we are calculating the average values of the each columns in the dataset.

# %% [markdown]
# `.describe()` returns useful summary statistics

# %%
data.describe()
# Out:
#                ID  Web of Science     Top 200  Google Scholar  Replications  \
# count   70.000000       70.000000   70.000000       70.000000     70.000000
# mean    52.485714       42.071429   22.257143      227.571429      0.742857
# std     31.465068       43.070660   23.182131      257.258375      1.741944
# min      2.000000        1.000000    0.000000        7.000000      0.000000
# 25%     23.250000       17.250000    9.000000       73.250000      0.000000
# 50%     48.500000       28.500000   15.000000      139.000000      0.000000
# 75%     81.750000       51.000000   23.750000      267.250000      1.000000
# max    104.000000      195.000000  108.000000     1246.000000      9.000000
#
#        Extensions       Both        Total
# count   70.000000  70.000000    70.000000
# mean     1.728571   2.471429   291.900000
# std      2.868729   3.794433   319.403935
# min      0.000000   0.000000     8.000000
# 25%      0.000000   0.000000   101.000000
# ...

# %% [markdown]
# describe() is used for calculating the statistical operations on the data. describe() is return the count,mean,std,min,max along with the 25%,50%,75%.

# %% [markdown]
# **Q3. Find the means of Top 200 and Google Scholar citations(10 points)**

# %%
datas = data[["Top 200","Google Scholar"]].mean()
print(datas)

datass = datas.mean(axis=0)
print(datass)
# Out:
# Top 200            22.257143
# Google Scholar    227.571429
# dtype: float64
# 124.91428571428573

# %% [markdown]
# here, we are calculating the means of the Top 200 and Google Scholar columns from the dataset.
#
# data[["Top 200","Google Scholar"]].mean() this is used for selecting only two columns from the dataset. for selecting only two columns here first we are using the df variable of the dataframe and passing two variables inside. which is used for calculates the mean of the each columns.
#
# here Top 200 mean is 22.26. while, Google Scholar mean is 227.57.
#
# datas.mean(axis=0) this is used for calculating the mean for the two different columns, here we are calculating the means of the mean using the datas.mean() function.
#
#  the final mean is 124.91 which is represent the average of the Top 200 and Google Scholar.
#
#  all in all, here we are first calculating the mean value of the Top 200 and Google Scholar and after getting this two mean again we are calculating the mean using the two mean values of the Top 200 and Google Scholar.

# %% [markdown]
# **Q4. Create a table of summary statistics of Top 200 citations and Google Scholar citations(10 points)**

# %%
import pandas as pd

summary_of_statistics = data[["Top 200", "Google Scholar"]].describe()

print(summary_of_statistics)
# Out:
#           Top 200  Google Scholar
# count   70.000000       70.000000
# mean    22.257143      227.571429
# std     23.182131      257.258375
# min      0.000000        7.000000
# 25%      9.000000       73.250000
# 50%     15.000000      139.000000
# 75%     23.750000      267.250000
# max    108.000000     1246.000000

# %% [markdown]
# Here, we are creating the table with the summary of statistics for the data "Top 200" and "Google Scholar". for calculating the summary statistics we are using the describe() function.
#
# Count is indicate the rows of the data where Top 200 and Google Scholar both have 70. this represent that there are total 70 entries are available in this both columns.
#
# talking about mean for the Top 200 is 22.257 while for Google Scholar is 227.57.
#
# std is stands for standard deviation.this is the measure of the spread or standard deviation.
# here the Top 200 standard deviation citation is 23.18.
# for Google Scholar standard deviation citation is 257.26.
#
# min is the rows where the minimum values observed in the columns. Top 200 citation is 0. Google Scholar citation is 7.
#
# 25%(percentile) : this row represent the 25% of the data.here Top 200 column 25% citation is 9. while, Google Scholar 25% citation is 73.25.
# 50% is rows that define median and middle value of the data which is stored in ascending order.Top 200 median value is citation 15. Google Scholar median value is citation 139.
# 75% (percentile) is shows that values are below the 75% of the data. here for the Top 200 75% citation value is 23.75.while, Google Scholar 75% citation is 267.25.
#
# Max is the rows with the maximum values observed in the columns. Top 200 column maximum value is 108 and for Google Scholar citation is 1246.
#
# all in all, here in this summary statistic represent the distribution and characteristics of the Top 200 and Google Scholar columns. here its include the central tendency, spread and various percentile of the data.

# %% [markdown]
# #### Create a table of summary statistics of the paper's fields (according to the variable `Field`)

# %%
data['Field'].describe()
# Out:
# count                  70
# unique                  5
# top       Macro/Int/Trade
# freq                   25
# Name: Field, dtype: object

# %% [markdown]
# ## Selecting and filtering

# %% [markdown]
# We can use integer slicing to select rows as follows

# %%
data[:5]
# Out:
#    ID                                              Title  Web of Science  \
# 0   2  Learning about a New Technology: Pineapple in ...             176
# 1   3       Multiple-Product Firms and Product Switching             111
# 2   4  Momma's Got the Pill": How Anthony Comstock an...              23
# 3   5              Matching and Sorting in Online Dating              75
# 4   6  Entry, Exit, and Investment-Specific Technical...               9
#
#    Top 200  Google Scholar            Field  Replications  Extensions  Both  \
# 0    108.0            1246      Development           1.0        10.0  11.0
# 1     74.0             764         Labor/IO           1.0         2.0   3.0
# 2     15.0              98         Labor/IO           2.0         0.0   2.0
# 3     23.0             326         Labor/IO           0.0         5.0   5.0
# 4      9.0              38  Macro/Int/Trade           0.0         0.0   0.0
#
#     Total
# 0  1530.0
# 1   949.0
# 2   136.0
# 3   424.0
# 4    56.0

# %% [markdown]
# We might want to find the top cited papers
#
# First we will sort our values by a column in the dataframe

# %%
pd.set_option('max_colwidth', 100)  # adjust column width

data[['Title', 'Google Scholar']].sort_values(by='Google Scholar', ascending=False)[:5]
# Out:
#                                                                                           Title  \
# 0                                           Learning about a New Technology: Pineapple in Ghana
# 21  The Macroeconomic Effects of Tax Changes: Estimates Based on a New Measure of Fiscal Shocks
# 33                   What Causes Industry Agglomeration? Evidence from Coagglomeration Patterns
# 1                                                  Multiple-Product Firms and Product Switching
# 15     Social Preferences, Beliefs, and the Dynamics of Free Riding in Public Goods Experiments
#
#     Google Scholar
# 0             1246
# 21            1245
# 33             766
# 1              764
# 15             736

# %% [markdown]
# Another way to select rows is to use row labels, ie. set a row index
#
# Similar to the column labels, we can add row labels (the index)

# %%
data.set_index('Title').head()
# Out:
#                                                                                                 ID  \
# Title
# Learning about a New Technology: Pineapple in Ghana                                              2
# Multiple-Product Firms and Product Switching                                                     3
# Momma's Got the Pill": How Anthony Comstock and Griswold v. Connecticut Shaped US Childbearing   4
# Matching and Sorting in Online Dating                                                            5
# Entry, Exit, and Investment-Specific Technical Change                                            6
#
#                                                                                                 Web of Science  \
# Title
# Learning about a New Technology: Pineapple in Ghana                                                        176
# Multiple-Product Firms and Product Switching                                                               111
# ...

# %% [markdown]
# Note: we haven't actually changed `data`

# %%
data.head()
# Out:
#    ID  \
# 0   2
# 1   3
# 2   4
# 3   5
# 4   6
#
#                                                                                             Title  \
# 0                                             Learning about a New Technology: Pineapple in Ghana
# 1                                                    Multiple-Product Firms and Product Switching
# 2  Momma's Got the Pill": How Anthony Comstock and Griswold v. Connecticut Shaped US Childbearing
# 3                                                           Matching and Sorting in Online Dating
# 4                                           Entry, Exit, and Investment-Specific Technical Change
#
#    Web of Science  Top 200  Google Scholar            Field  Replications  \
# 0             176    108.0            1246      Development           1.0
# 1             111     74.0             764         Labor/IO           1.0
# 2              23     15.0              98         Labor/IO           2.0
# ...

# %% [markdown]
# We need to reassign the variable name `data` to the new copy

# %%
# data.reset_index(inplace=True)   # Uncomment this if you receive an error

data = data.set_index('Title')   # Can also use data.set_index('Title', inplace=True)
data.head()
# Out:
#                                                                                                 ID  \
# Title
# Learning about a New Technology: Pineapple in Ghana                                              2
# Multiple-Product Firms and Product Switching                                                     3
# Momma's Got the Pill": How Anthony Comstock and Griswold v. Connecticut Shaped US Childbearing   4
# Matching and Sorting in Online Dating                                                            5
# Entry, Exit, and Investment-Specific Technical Change                                            6
#
#                                                                                                 Web of Science  \
# Title
# Learning about a New Technology: Pineapple in Ghana                                                        176
# Multiple-Product Firms and Product Switching                                                               111
# ...

# %% [markdown]
# **Q5 Give all the column values which contains "Investment and Usage of New Technologies: Evidence from a Shared ATM Network" in the 'title' field(5 points)**

# %%
data.loc[['Investment and Usage of New Technologies: Evidence from a Shared ATM Network']]
# Out:
#                                                                               ID  \
# Title
# Investment and Usage of New Technologies: Evidence from a Shared ATM Network  42
#
#                                                                               Web of Science  \
# Title
# Investment and Usage of New Technologies: Evidence from a Shared ATM Network               7
#
#                                                                               Top 200  \
# Title
# Investment and Usage of New Technologies: Evidence from a Shared ATM Network      5.0
#
#                                                                               Google Scholar  \
# Title
# Investment and Usage of New Technologies: Evidence from a Shared ATM Network              14
#
#                                                                                  Field  \
# Title
# Investment and Usage of New Technologies: Evidence from a Shared ATM Network  Labor/IO
#
# ...

# %% [markdown]
# Here, we are finding one row or searching one row along with all columns using the .loc[] which is used for finding the particular data.
#  here, we are finding the row which have the title as a Investment and Usage of New Technologies: Evidence from a Shared ATM Network for finding this we are using the .loc.
#
#  ID is the unique number of the data row here its 42 so its row 42 which is matched. Id is the column.
#
#  web of services is the column which is 7, defines that this are the number of citations.
#
#  Top 200 is have 5 citation which represent that total 200 papers have 5 citation.
#
# Google Scholar is 14 citation which means that for paper and publication its at 14.
#
# Field is Labor/IO which is indicates that this is related to labor economics or industrial organizations.
#
# about Replication so , there is no replication for this research paper.
#
# extensions there is no extensions for this research paper.
#
# both is specify the total number of replications and extensions which is 1.
#
# all in all here we are finding the research paper related data for data analysis about the data. here there is moderate number of the citation for the Google Scholar and related other extensions. and about replications and expectations are not reported for this paper.

# %%
data.loc[['Matching and Sorting in Online Dating',
          'Learning about a New Technology: Pineapple in Ghana']]
# Out:
#                                                      ID  Web of Science  \
# Title
# Matching and Sorting in Online Dating                 5              75
# Learning about a New Technology: Pineapple in Ghana   2             176
#
#                                                      Top 200  Google Scholar  \
# Title
# Matching and Sorting in Online Dating                   23.0             326
# Learning about a New Technology: Pineapple in Ghana    108.0            1246
#
#                                                            Field  \
# Title
# Matching and Sorting in Online Dating                   Labor/IO
# Learning about a New Technology: Pineapple in Ghana  Development
#
#                                                      Replications  Extensions  \
# Title
# Matching and Sorting in Online Dating                         0.0         5.0
# Learning about a New Technology: Pineapple in Ghana           1.0        10.0
#
# ...

# %% [markdown]
# Alternatively, we can filter our dataframe (select rows) using *boolean conditions*

# %%
data.reset_index(inplace=True)

data['Field'] == 'Development'
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 65    False
# 66    False
# 67    False
# 68    False
# 69    False
# Name: Field, Length: 70, dtype: bool

# %% [markdown]
# Selecting rows with this boolean condition will return only rows of the dataframe where `Field == 'Development'` is `True`

# %%
data[data['Field'] == 'Development']
# Out:
#                                                                                                   Title  \
# 0                                                   Learning about a New Technology: Pineapple in Ghana
# 7                                                            Multinationals and Anti-Sweatshop Activism
# 42  Determinants of Redistributive Politics: An Empirical Analysis of Land Reforms in West Bengal, I...
# 45                                    Watta Satta: Bride Exchange and Women's Welfare in Rural Pakistan
# 55                                                                           Inherited Trust and Growth
# 64                  Can Higher Prices Stimulate Product Use? Evidence from a Field Experiment in Zambia
#
#     ID  Web of Science  Top 200  Google Scholar        Field  Replications  \
# 0    2             176    108.0            1246  Development           1.0
# 7    9              21      8.0             134  Development           0.0
# ...

# %%
data[(data['Field'] == 'Development') & (data['Web of Science'] > 100)]
# Out:
#                                                   Title  ID  Web of Science  \
# 0   Learning about a New Technology: Pineapple in Ghana   2             176
# 55                           Inherited Trust and Growth  85             102
#
#     Top 200  Google Scholar        Field  Replications  Extensions  Both  \
# 0     108.0            1246  Development           1.0        10.0  11.0
# 55     44.0             536  Development           3.0         3.0   6.0
#
#      Total
# 0   1530.0
# 55   682.0

# %% [markdown]
# **Q6. How many papers in the sample have over 100 Google Scholar citations?
#  Hint: use `len()` to find the length of a dataframe ( 5 points)**

# %%
papers_over_100_google_scholar = data[data['Google Scholar'] > 100]

count_papers_over_100_google_scholar = len(papers_over_100_google_scholar)

print(count_papers_over_100_google_scholar)
# Out:
# 44

# %% [markdown]
# Here, we are calculating the number of the papers in the sample of the 100 Google Scholar citations.
#
# papers_over_100_google_scholar = data[data['Google Scholar'] > 100] here we are using the filter for the dataset for select only google scholar column which have the greate than 100. this is define that more than 100 google citation.
#
# count_papers_over_100_google_scholar = len(papers_over_100_google_scholar) after doing the filtering the dataset, here we are calculating the length of the dataframe. here length represent the number of rows in the dataframe, here its match with the number of papers which match the condition.
#
# Here, focusing on the final result its 44 which define that there are total 44 papers which are over 100 Google Scholar citations.
#
# all in all, this is identifies as the count the papers of the sample with more than 100 google scholar citations, and the final result is 44 of the papers from the 100 google scholar.

# %% [markdown]
# #### How many 'Labor/IO' papers have over 100 Google Scholar citations?

# %%
len(data[(data['Google Scholar'] > 100) & (data['Field'] == 'Labor/IO')])
# Out:
# 10

# %% [markdown]
# ## Grouping and aggregating data

# %% [markdown]
# We might want to summarize our data by grouping it by fields
#
# To do this, we will use the `.groupby()` function

# %%
data.reset_index(inplace=True)

grouped = data.groupby('Field')
grouped

# %% [markdown]
# To return an *aggregated* dataframe, we need to specify the function we would like pandas to use to aggregate our groups

# %%
grouped.mean()
# Out:
# <ipython-input-25-eca914d15133>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped.mean()
#                      index         ID  Web of Science    Top 200  \
# Field
# Applied (gen.)   32.428571  49.285714       33.428571  13.142857
# Behavioral/Exp.  42.631579  65.000000       48.842105  24.000000
# Development      35.500000  55.000000       60.166667  32.333333
# Labor/IO         23.846154  35.923077       46.384615  26.461538
# Macro/Int/Trade  34.200000  51.880000       32.760000  18.880000
#
#                  Google Scholar  Replications  Extensions      Both  \
# Field
# Applied (gen.)       199.714286      0.857143    0.571429  1.428571
# Behavioral/Exp.      202.789474      1.631579    3.421053  5.052632
# Development          380.166667      0.666667    2.666667  3.333333
# ...

# %%
grouped['Both'].mean()
# Out:
# Field
# Applied (gen.)     1.428571
# Behavioral/Exp.    5.052632
# Development        3.333333
# Labor/IO           1.384615
# Macro/Int/Trade    1.160000
# Name: Both, dtype: float64

# %%
grouped['Both'].agg(['mean', 'median', 'count'])
# Out:
#                      mean  median  count
# Field
# Applied (gen.)   1.428571     1.0      7
# Behavioral/Exp.  5.052632     4.0     19
# Development      3.333333     1.5      6
# Labor/IO         1.384615     1.0     13
# Macro/Int/Trade  1.160000     0.0     25

# %% [markdown]
# A list of built-in aggregatation functions can be found [here](http://pandas.pydata.org/pandas-docs/stable/basics.html#descriptive-statistics)
#
# ## Plotting
#
# Pandas provides a built-in plotting command to create `matplotlib` plots from your dataframes
#
# To display our plots, we need to import first `matplotlib`

# %%
import matplotlib.pyplot as plt

grouped['Google Scholar'].mean().plot(kind='bar')
plt.show()

# %% [markdown]
# **Q7. What does alpha = 0.6 represent in the below code. Explain.(5 points)**

# %%
data.plot(x='Google Scholar', y='Both', kind='scatter', alpha=0.6)
plt.ylabel('Total replications and extensions')
plt.xlabel('Number of citations')
plt.grid()
plt.show()

# %% [markdown]
# Here , we are creating the scatter plot for number of citation and total replications and extensions. looking in the diagram the highest citation is above the 1200 while, total replications and extensions the highest is above the 17.5.
#
# here  we are setting the alpha values is 0.6 which is used for the plot for controlling the transparancy of the scatterplot points. this is used for the optacity or alpha channel for the plotted points.
#
# Alpha represent the optacity of the scatterplot points. which is used for controling the transparancy of the data points. this alpha value ranges is between 0 and 1.
# Here. 0 is the complete transparent. which is totally not visible. 1 is represent the complete opaque which is set as a fully visible.
#
# here alpha=0.6 which means that the points in the scatterplot is used for using the moderate level of the transperancy for the data point. this is used if the dataset have the large number of the data point and its overlaping to each other. here if we resuce the optacity we can make the points visible after the overlapping also this is represent the data density.
#
# all in all, alpha=0.6 is represent the moderate level of the transparancy for the scatterplot points. this is making the point little bit visible while distributing the data points effectively.

# %% [markdown]
# **Q8. Give the bar Plot the average number of replications and extensions for each field, sorted from highest to lowest(10 points)**

# %%
data=pd.read_csv("/content/data.csv")
data.head(5)
# Out:
#    ID  \
# 0   2
# 1   3
# 2   4
# 3   5
# 4   6
#
#                                                                                             Title  \
# 0                                             Learning about a New Technology: Pineapple in Ghana
# 1                                                    Multiple-Product Firms and Product Switching
# 2  Momma's Got the Pill": How Anthony Comstock and Griswold v. Connecticut Shaped US Childbearing
# 3                                                           Matching and Sorting in Online Dating
# 4                                           Entry, Exit, and Investment-Specific Technical Change
#
#    Web of Science  Top 200  Google Scholar            Field  Replications  \
# 0             176    108.0            1246      Development           1.0
# 1             111     74.0             764         Labor/IO           1.0
# 2              23     15.0              98         Labor/IO           2.0
# ...

# %%
df=data[["Replications","Extensions"]].mean()
print(df)
# Out:
# Replications    0.742857
# Extensions      1.728571
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

mean_replications_extensions = data.groupby('Field')[['Replications', 'Extensions']].mean()

mean_replications_extensions = mean_replications_extensions.sort_values(by='Replications', ascending=False)

mean_replications_extensions.plot(kind='bar', stacked=True)
plt.title('Average Replications and Extensions by Field')
plt.xlabel('Field')
plt.ylabel('Average Replications and Extensions')
plt.legend(title='Metric', loc='upper right', labels=['Replications', 'Extensions'])
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# Here we are first calculating the mean for the replications and expections for each field and create the bar diagram for displaying the results.
#
# pandas library is used for group the data by the field column and here we are calculating the  mean for the replications and expectations columns.
#
# which is we are sorting the results based on the replications in the descending order using the sort value.
#
# here we are creating the stacked bar diagram using the matplotlib libraries for visualize the number of replications and extensions for each of the field.
#
# here we are giving the labels for the x and y-axis , the lebels are set to provide the information about the data. where x-axis have the field names while the y-axis have the average of the replications and expectations.
#
# plt.xticks(rotation=45) this one is used for rotates the x-axis labels into 45 degrees for preventing the issue of overlapping if there is more field.
#
# plt.show() is used for displaying the diagram.
#
# focusing on the colors blue is determine the replications and orange is determine the expectations.
# focusing on the bar graph, its shows that the highest mean of average replications and expections is at 5 for the Behavioural and exp while , the smallest average for the replications and expectations are above at 1 for the Macro/Int/Trade. talking about the average for the field development is with average replications and expectations at 3.5.
#
# all in all, we are here calculating the average of the replications and expectations and making the prediction based on the field column values. focusing on the data the highest average is behavioural/Exp at 5. in contrast, focusing on the lowest average then its Macro/Int/Trade which is at above 1.

# %% [markdown]
# ## Another plotting library: `seaborn`
#
# * `seaborn` is a plotting library built on top of `matplotlib`
#
# * It is geared towards producing pretty plots for statistical applications
#
# * You can find an example gallery of `seaborn` plots [here](https://seaborn.pydata.org/examples/index.html)

# %%
import seaborn as sns  # Import the package

# %% [markdown]
# **Q9. Make a joint plot for 'Google Scholar' on x - axis and 'Both' on y axis  and visualize it(10 points)**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv("/content/data.csv")


sns.set(style="whitegrid")
sns.jointplot(data=data, x='Google Scholar', y='Both', kind='scatter')

plt.xlabel('Google Scholar')
plt.ylabel('Both')

plt.show()

# %% [markdown]
# here, we are making the joint plot for the Google Scholar and Both, where X-axis is for Google Scholar and in the y-axis for the Both and create join scatter plot diagram.
#
# here fisrt we are loading the data from the CSV file, here we are using the seaborn library for create the joint point that visualiza the relation between the two variables of Google Scholars and Both using the scatterplot.
#
# here we are loading the data from the csv file using the pd.read_csv() function using the file path inside and its stored in the one variable data.
#
# seaborn configuration  this is the seaborn style for the whitegrid for the better visualization.
#
# Joint plot this is sns jointplot function which is use for creating the joint plot. which is specify the data from the dataframe such as data,set,google scholar' all are in the x-axis variable and noth is at the y-axis variable, and here its define as the plot type of the scatterplot using the kind=scatter.
#
# labels are used for labeling the x-axis  to google scholar and y-axis as a both using the plt.labels.
#
# visualization for display the graph here we are using matplotlib so plt.show() is used for displaying the graph.
#
# Focusing on the graph its shows that highest Google Scolar is above the 1200 while the highest both is above 17.5 in contrast majority of the data points are at 0.0 which indicates the correlation between the two variables.
#
# all in all, this joint plot represent the distribution of the data and correlation between the Google Scholar and Both variables. this is used for understanding the pattern between this two columns data.

# %%
sns.kdeplot(data=data[data['Replications'] > 0].loc[:, 'Web of Science'], cumulative=True, bw=2)
sns.kdeplot(data=data[data['Replications'] == 0].loc[:, 'Web of Science'], cumulative=True, linestyle='--', bw=2)
plt.xlim(0, 200)
plt.xlabel('Web of Science Citations')
plt.ylabel('CDF')
plt.legend(['One or more replications', 'No replications'])
plt.show()
# Out:
# <ipython-input-35-d770e5eddac2>:1: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=2`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.13.0.
#
#   sns.kdeplot(data=data[data['Replications'] > 0].loc[:, 'Web of Science'], cumulative=True, bw=2)
# <ipython-input-35-d770e5eddac2>:2: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=2`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.13.0.
#
#   sns.kdeplot(data=data[data['Replications'] == 0].loc[:, 'Web of Science'], cumulative=True, linestyle='--', bw=2)

# %% [markdown]
# Here, we are creating diagram which is represent data for web of science and CDF. where x-axis labeled as web of science citations and y-axis labeled as CDF.
#
# for creating this graph we are using sns.kdeplot which is used for creating the graph with different data lines. here straight blue line is indicating the one or more replications and broken orange lines indicate no replications. the blue is all the way upside straight in continues manner while orange broken line is a bit curve with different data points and its in increasing order but not in straight line. after 125 web of science its started in steady upto 200.

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ## Bokeh example
#
# Bokeh is a Python library that makes creating interactive plots super easy - an example gallery is [here](http://bokeh.pydata.org/en/latest/docs/gallery.html)

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import ColumnDataSource, HoverTool
output_notebook()

# Add data source
source = ColumnDataSource(data[['ID', 'Web of Science', 'Replications', 'Extensions']])
colors = ['red', 'blue']

# Add title tooltips
hover = HoverTool(tooltips=[
    ("Title", "@Title"),
    ("(x,y)", "($x, $y)")
])

# Create figure
p = figure(tools=[hover])

# Plot scatter
for to_plot, color in zip(['Replications', 'Extensions'], colors):
    p.circle(x='Web of Science', y=to_plot, source=source, size=7, alpha=0.5, legend=[to_plot.title()], color=color)

p.legend.click_policy = 'hide'
p.xaxis.axis_label = 'Number of citations'
p.yaxis.axis_label = 'Number of replications or extensions'

show(p)

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

df=pd.read_csv("/content/data.csv")
x=df['Replications']
y=df['Extensions']
p = figure(title="Simple Scatter Plot", x_axis_label="X-axis", y_axis_label="Y-axis")

# Add data to the figure
p.circle(x, y, size=10, color="blue", alpha=0.5)

# Display the plot in a Jupyter Notebook
output_notebook()
show(p)
# Out:
#   <div id="c2dabb1d-0ee5-4a7e-9004-9584b1965702" data-root-id="p1036" style="display: contents;"></div>

# %% [markdown]
# Here,we are using bokeh graph, for creating graph we are using the bokeh plotting diagram. where x-axis have range between 0 to 8 and y-axis have range between 0 to 15. where x is replications data and y is having expectation data. here we are using the alpha=45 for changing the optacity of the data points for clearly visualize the all data points. dark blue data points is one to more data point in same position while light blue is the single data points.
#
# focusing on the graph its clearly see that all the data points are in between the 0 to 10 range in y-axis and for x-axis is upto 8 but there is two outliers one is the datapoint in y-axis which is upto 15 and another one is into x-axis which is after 8 this both are consider as outliers.

# %% [markdown]
# ## Other resources
#
# Here are some free, online resources for learning pandas/matplotlib:
#
# * QuantEcon lectures: [Pandas](https://lectures.quantecon.org/py/pandas.html), [Pandas for Panel Data](https://lectures.quantecon.org/py/pandas_panel.html), [Matplotlib](https://lectures.quantecon.org/py/matplotlib.html)
# * QuantEcon [Stata-R-Pandas cheatsheet](https://cheatsheets.quantecon.org/stats-cheatsheet.html)
# * SciPy 2017: [Anatomy of Matplotlib](https://www.youtube.com/watch?v=rARMKS8jE9g)
# * Coursera/University of Michigan: [Introduction to Data Science in Python](https://www.coursera.org/learn/python-data-analysis)
